# %%
# using api one can connect to the database of company or api helps to connect two software

# %%
import pandas as pd
import requests

# %%
response = requests.get("https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page=1")

# %%
response.json()
# Out:
# {'page': 1,
#  'results': [{'adult': False,
#    'backdrop_path': '/rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg',
#    'genre_ids': [18, 80],
#    'id': 238,
#    'original_language': 'en',
#    'original_title': 'The Godfather',
#    'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#    'popularity': 147.571,
#    'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#    'release_date': '1972-03-14',
#    'title': 'The Godfather',
#    'video': False,
#    'vote_average': 8.7,
#    'vote_count': 18395},
#   {'adult': False,
#    'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#    'genre_ids': [18, 80],
#    'id': 278,
#    'original_language': 'en',
#    'original_title': 'The Shawshank Redemption',
# ...

# %%
response.json()['results']
# Out:
# [{'adult': False,
#   'backdrop_path': '/rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg',
#   'genre_ids': [18, 80],
#   'id': 238,
#   'original_language': 'en',
#   'original_title': 'The Godfather',
#   'overview': 'Spanning the years 1945 to 1955, a chronicle of the fictional Italian-American Corleone crime family. When organized crime family patriarch, Vito Corleone barely survives an attempt on his life, his youngest son, Michael steps in to take care of the would-be killers, launching a campaign of bloody revenge.',
#   'popularity': 147.571,
#   'poster_path': '/3bhkrj58Vtu7enYsRolD1fZdja1.jpg',
#   'release_date': '1972-03-14',
#   'title': 'The Godfather',
#   'video': False,
#   'vote_average': 8.7,
#   'vote_count': 18395},
#  {'adult': False,
#   'backdrop_path': '/kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg',
#   'genre_ids': [18, 80],
#   'id': 278,
#   'original_language': 'en',
#   'original_title': 'The Shawshank Redemption',
# ...

# %%
pd.DataFrame(response.json()['results']).head(2)
# Out:
#    adult                     backdrop_path genre_ids   id original_language  \
# 0  False  /rSPw7tgCH9c6NqICZef4kZjFOQ5.jpg  [18, 80]  238                en
# 1  False  /kXfqcdQKsToO0OUXHcrrNCHDBzO.jpg  [18, 80]  278                en
#
#              original_title  \
# 0             The Godfather
# 1  The Shawshank Redemption
#
#                                             overview  popularity  \
# 0  Spanning the years 1945 to 1955, a chronicle o...     147.571
# 1  Framed in the 1940s for the double murder of h...     115.076
#
#                         poster_path release_date                     title  \
# 0  /3bhkrj58Vtu7enYsRolD1fZdja1.jpg   1972-03-14             The Godfather
# 1  /lyQBXzOQSuE59IsHyhrp0qIiPAz.jpg   1994-09-23  The Shawshank Redemption
#
#    video  vote_average  vote_count
# 0  False           8.7       18395
# 1  False           8.7       24318

# %%
pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
# Out:
#         id                                          title  \
# 0      238                                  The Godfather
# 1      278                       The Shawshank Redemption
# 2      240                          The Godfather Part II
# 3      424                               Schindler's List
# 4    19404                    Dilwale Dulhania Le Jayenge
# 5      389                                   12 Angry Men
# 6      129                                  Spirited Away
# 7   372058                                     Your Name.
# 8   496243                                       Parasite
# 9      155                                The Dark Knight
# 10     497                                 The Green Mile
# 11  569094            Spider-Man: Across the Spider-Verse
# 12     680                                   Pulp Fiction
# 13      13                                   Forrest Gump
# 14     122  The Lord of the Rings: The Return of the King
# ...

# %%
df = pd.DataFrame()

# %%
for i in range(1,429):
  response =  requests.get(f"https://api.themoviedb.org/3/movie/top_rated?api_key=8265bd1679663a7ea12ac168da84d2e8&language=en-US&page={i}")
  temp_df = pd.DataFrame(response.json()['results'])[['id','title','overview','release_date','popularity','vote_average','vote_count']]
  df = df.append(temp_df, ignore_index = True)
# Out:
# <ipython-input-9-dbbcce800ba5>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df, ignore_index = True)
# <ipython-input-9-dbbcce800ba5>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df, ignore_index = True)
# <ipython-input-9-dbbcce800ba5>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df, ignore_index = True)
# <ipython-input-9-dbbcce800ba5>:4: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df = df.append(temp_df, ignore_index = True)
# ...

# %%
df
# Out:
#           id                           title  \
# 0        238                   The Godfather
# 1        278        The Shawshank Redemption
# 2        240           The Godfather Part II
# 3        424                Schindler's List
# 4      19404     Dilwale Dulhania Le Jayenge
# ...      ...                             ...
# 8555    2575            The Tailor of Panama
# 8556  864873                        Hypnotic
# 8557  550201                        The Pool
# 8558   14400  The Heir Apparent: Largo Winch
# 8559   13282                 Death Race 2000
#
#                                                overview release_date  \
# 0     Spanning the years 1945 to 1955, a chronicle o...   1972-03-14
# 1     Framed in the 1940s for the double murder of h...   1994-09-23
# 2     In the continuing saga of the Corleone crime f...   1974-12-20
# 3     The true story of how businessman Oskar Schind...   1993-12-15
# 4     Raj is a rich, carefree, happy-go-lucky second...   1995-10-20
# ...

# %%
df.shape
# Out:
# (8560, 7)

# %%
df.to_csv('movies.csv')
